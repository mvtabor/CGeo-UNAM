# %%
using PyPlot

# %%
;ls
# Out:
# CMTMex.txt
# CMTVerano.ipynb
# Untitled.ipynb

# %%
data  = readdlm("CMTMex.txt")
# Out:
# 429×10 Array{Float64,2}:
#  -109.75  20.26  1977.72   9.0  21.0  5.81  15.0  13.0  15.0  59.3
#  -113.1   29.07  1977.89  11.0  21.0  5.99  15.0   2.0  50.0   4.5
#  -104.62  15.38  1978.81  10.0  22.0  5.62  15.0  14.0   7.0   0.299987
#  -111.67  27.81  1978.9   11.0  26.0  5.56  15.0   7.0  44.0   8.30001
#  -114.73  30.57  1978.91  11.0  29.0  5.35  15.0  14.0  37.0  50.0
#  -110.45  26.17  1978.94  12.0  10.0  5.31  15.0   6.0  40.0   2.79999
#  -112.84  28.16  1979.15   2.0  22.0  5.31  15.0  22.0  53.0  24.0
#  -110.99  26.64  1979.22   3.0  23.0  5.57  15.0  17.0  21.0  60.0
#  -115.57  32.62  1979.79  10.0  15.0  6.51  12.0  23.0  17.0   0.800006
#  -115.99  32.82  1979.79  10.0  16.0  5.14  10.1   6.0  19.0  54.2
#  -116.15  32.75  1979.79  10.0  16.0  5.61  10.0   6.0  58.0  49.2
#  -115.36  32.26  1980.44   6.0   9.0  6.33  10.1   3.0  28.0  29.3
#  -109.99  25.95  1980.45   6.0  13.0  5.52  15.0   1.0   4.0  40.7
#     ⋮                                 ⋮
# ...

# %%
plot(data[:,3],data[:,6],"o")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fc4a4f519d0>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fc4a2b29350>

# %%
plot(data[:,1],data[:,2],"o")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fc4a2890ad0>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fc4a27ae050>

# %%
using Plots
# Out:
# INFO: Recompiling stale cache file /home/acer/.julia/lib/v0.6/PlotUtils.ji for module PlotUtils.
# INFO: Recompiling stale cache file /home/acer/.julia/lib/v0.6/PlotThemes.ji for module PlotThemes.
# INFO: Recompiling stale cache file /home/acer/.julia/lib/v0.6/Showoff.ji for module Showoff.
# INFO: Recompiling stale cache file /home/acer/.julia/lib/v0.6/NaNMath.ji for module NaNMath.
# INFO: Recompiling stale cache file /home/acer/.julia/lib/v0.6/Measures.ji for module Measures.
# WARNING: using Plots.plot in module Main conflicts with an existing identifier.

# %%
histogram(data[:,6],color="orange")
# Out:
# <img src="data:image/png;base64,..." />

# %%
histogram(data[:,7],color="blue")
# Out:
# <img src="data:image/png;base64,..." />

# %%
Mag = data[:,6];
Mc = 5.1;
M = mean(Mag);
Mbin=0.1;
z = (log10(eu));
b = z / ((M)-(Mc-(Mbin/2)))
# Out:
# 1.1785952222703333

# %% [markdown]
# Con una magintud mínima de completitud, Mc=5.0, obtenemos una b=0.9270192692630838; con Mc=5.2, obtenemos una b=1.6175753840640248. SIento la ideonea, una Mc=5.1 para que quede en el rango.
